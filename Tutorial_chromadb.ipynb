# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (2.6.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.51.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.16.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.43.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (1.82.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\shrey\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=24.0 in c:\users\shrey\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\shrey\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\shrey\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\shrey\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\shrey\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\shrey\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\shrey\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\users\shrey\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: flatbuffers in c:\users\shrey\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\users\shrey\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.35.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.43.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-proto==1.43.0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.43.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in c:\users\shrey\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.64b0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\shrey\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\shrey\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\shrey\anaconda3\lib\site-packages (from pydantic-settings>=2.0->chromadb) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\shrey\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.23.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\shrey\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.4.2)
# Requirement already satisfied: httptools>=0.8.0 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\shrey\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\shrey\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\shrey\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shrey\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\shrey\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\shrey\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\shrey\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
# Installing collected packages: chromadb
# Successfully installed chromadb-1.5.9

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids = ['id1', 'id2']
)
# Out:
# C:\Users\shrey\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████| 79.3M/79.3M [02:18<00:00, 602kiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
documents = collection.get(ids=["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This document is about New York'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts=["Query is about Chhole Bhature"],
    n_results=2
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.5588476657867432, 1.8114911317825317]]}

# %%
results = collection.query(
    query_texts=['Query is about big apple'],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.631218671798706, 1.867558479309082]]}

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids=["id3", "id4"],
    metadatas=[
        {"url": "https://en.wikipedia.org/wiki/New_York_City"},
        {"url": "https://en.wikipedia.org/wiki/New_Delhi"}
    ]
)

# %%
results = collection.query(
    query_texts=["Query is about Chhole Bhature"],
    n_results=2
)
results
# Out:
# {'ids': [['id2', 'id4']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, {'url': 'https://en.wikipedia.org/wiki/New_Delhi'}]],
#  'distances': [[1.5588476657867432, 1.5588476657867432]]}
